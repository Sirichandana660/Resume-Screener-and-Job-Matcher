# %%
import pandas as pd

# file paths
resume_path = "../data/extracted/archive/training_data.csv"
jobs_path = "../data/extracted/archive/job_roles.csv"

# load datasets
resumes = pd.read_csv(resume_path)
jobs = pd.read_csv(jobs_path)

print("Resumes shape:", resumes.shape)
print("Jobs shape:", jobs.shape)

resumes.head()

# %%
import pandas as pd
print("Pandas loaded successfully")
